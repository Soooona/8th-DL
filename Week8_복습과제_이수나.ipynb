# %% [markdown]
# # **U-Net 모델 구현**
#
# ✅ 아래 코드는 PyTorch로 작성한 간단한 U-Net 모델입니다.
#
# ✅ 주요 목표: 작은 이미지 세트로 segmentation 학습을 테스트하기!
#
# ✅ 특징: 업샘플링(deconv/upsample 선택 가능), 입력 스케일링, Gaussian noise 추가, 배치 정규화 적용

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# --- 작은 U-Net 정의 ---
class UNetSmall(nn.Module):
    def __init__(self, upsample_mode='deconv', net_scaling=None, edge_crop=0, gaussian_noise_std=0.1):
        super().__init__()
        self.net_scaling = net_scaling
        self.edge_crop = edge_crop
        self.gaussian_noise_std = gaussian_noise_std
        self.upsample_mode = upsample_mode

         # Convolution Block: Conv -> ReLU -> Conv -> ReLU
        def conv_block(in_c, out_c):
            return nn.Sequential(
                nn.Conv2d(in_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True),
                nn.Conv2d(out_c, out_c, 3, padding=1),
                nn.ReLU(inplace=True)
            )

        # 인코더 부분 목표 -> 128 까지!
        self.enc1 = conv_block(3, 16)
        self.enc2 = conv_block(16,32)
        self.enc3 = conv_block(32,64)
        self.enc4 = conv_block(64,128)
        # Bottleneck
        self.center = conv_block(128, 128)
        self.pool = nn.MaxPool2d(2)


        # 업샘플링 부분 정의 (deconv 또는 upsample+conv) 로
        if upsample_mode == 'deconv':
            def upsample_layer(in_c, out_c):
                return nn.ConvTranspose2d(in_c, out_c, 2, stride=2)
        else:
            def upsample_layer(in_c, out_c):
                return nn.Sequential(
                    nn.Upsample(scale_factor=2, mode='nearest'),
                    nn.Conv2d(in_c, out_c, 1)
                )
        # 디코더 부분
        self.up4 = upsample_layer(128, 128)
        self.dec4 = conv_block(128+128, 64)
        self.up3 = upsample_layer(64,64)
        self.dec3 = conv_block(64+64, 32)
        self.up2 = upsample_layer(32,32)
        self.dec2 = conv_block(32+32,16)
        self.up1 = upsample_layer(16,16)
        self.dec1 = conv_block(16+16,16)

        # 최종 출력: 1채널(segmentation mask)
        self.final = nn.Conv2d(16,1,1)

    def forward(self, x):
        if self.net_scaling:
        # 입력 스케일링
            x = F.avg_pool2d(x, self.net_scaling)
        # Gaussian noise 추가
        if self.gaussian_noise_std:
            noise = torch.randn_like(x) * self.gaussian_noise_std
            x = x + noise

        # 배치 정규화 적용
        x = F.batch_norm(x, running_mean=None, running_var=None, training=True)

        # 인코더
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))
        # Bottleneck
        center = self.center(self.pool(e4))

        # 디코더 + Skip Connection
        d4 = self.up4(center)
        d4 = torch.cat((d4,e4), dim=1)
        d4 = self.dec4(d4)

        d3 = self.up3(d4)
        d3 = torch.cat((d3,e3), dim=1)
        d3 = self.dec3(d3)

        d2 = self.up2(d3)
        d2 = torch.cat((d2,e2), dim=1)
        d2 = self.dec2(d2)

        d1 = self.up1(d2)
        d1 = torch.cat((d1,e1), dim=1)
        d1 = self.dec1(d1)

        out = self.final(d1)
        out = torch.sigmoid(out)
         # Crop + Pad
        if self.edge_crop > 0:
            out = out[:, :, self.edge_crop:-self.edge_crop, self.edge_crop:-self.edge_crop]
            out = F.pad(out, (self.edge_crop, self.edge_crop, self.edge_crop, self.edge_crop))
        # Upsample 다시 확대
        if self.net_scaling:
            out = F.interpolate(out, scale_factor=self.net_scaling, mode='nearest')

        return out

# %% [markdown]
# ## **학습용 데이터 생성하기**

# %%
batch_size = 32
x = torch.randn(batch_size, 3, 128, 128)  # RGB 이미지
y = (torch.rand(batch_size, 1, 128, 128) > 0.5).float()  # 랜덤 이진 마스크

dataset = TensorDataset(x, y)
loader = DataLoader(dataset, batch_size=2, shuffle=True)

# %% [markdown]
# ## **데이터 시각화**

# %%
import matplotlib.pyplot as plt
# 첫 번째 이미지를 시각화
sample_x = x[0]
sample_y = y[0]

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(sample_x.permute(1, 2, 0).numpy())
plt.title('Input Image')

plt.subplot(1, 2, 2)
plt.imshow(sample_y.squeeze().numpy(), cmap='gray')
plt.title('Ground Truth Mask')
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.1416545..4.484799].

# %% [markdown]
# ## **모델 선언 및 학습**

# %%
# --- 모델 선언 및 학습 ---
model = UNetSmall(upsample_mode='deconv', net_scaling=None, edge_crop=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.BCELoss()

# 간단히 30 epoch만
for epoch in range(10):
    model.train()
    total_loss = 0
    for xb, yb in loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss/len(loader):.4f}")
# Out:
# Epoch 1, Loss: 0.6935
# Epoch 2, Loss: 0.6932
# Epoch 3, Loss: 0.6931
# Epoch 4, Loss: 0.6931
# Epoch 5, Loss: 0.6931
# Epoch 6, Loss: 0.6931
# Epoch 7, Loss: 0.6930
# Epoch 8, Loss: 0.6930
# Epoch 9, Loss: 0.6929
# Epoch 10, Loss: 0.6928

# %% [markdown]
# ## **아래 주석을 풀고 U-Net 모델에 대해 간단히 설명해주세요 😀**

# %% [markdown]
# [답변]
#
#
# ---
#
# U-Net은 주로 이미지 분할(segmentation)에 쓰이는 딥러닝 구조이다.
# * U자형 구조
#     * 왼쪽 '수축(contraction) 경로': 입력 이미지를 점차 축소하며 특징(feature)을 추출
#     * 오른쪽 '팽창(expansion)경로': 축소된 특징 지도를 다시 원래 크기로 복원하며 픽셀 단위 예측
# * 기본 U-Net은 64 -> 128 -> 256... 채널로 깊어지지만, 필요한 만큼 층수나 채널 수를 줄여 "작은 U-Net"으로도 구현 가능하다

# %% [markdown]
# ## **아래 주석을 풀고 DeepLabv1, v2, v3. v3+  모델에 대해 각각 간단히 설명해주세요 🐶**

# %% [markdown]
# [답변]
#
#
# ---
#
# [DeepLab v1]: 확장된 커널(Atrous 을Convolution)을 사용해서 이미지 해상도는 그대로 두고 더 넓은 주변 정보를 파악한다. 마지막에 Conditional Random Field(CRF)라는 알고리즘으로 픽셀 경계를 다듬에 결과 마스크의 테두리가 부드럽고 정확해짐 -> 확장된 필터 + CRF
#
# [DeepLab v2]: 서로 다른 크기의 "Atrous Convolution"을 병렬로 사용해서 다양한 크기에 대응함.(ASPP) -> v1과 기본 아이디어는 동일하지만, 여러 크기를 동시에 볼 수 있게 됨.
#
# [DeepLab v3]: ASPP에 "이미지 전체 평균"피처를 쌓아서 멀리 떨어진 픽셀 사이의 관계도 고려하고, 무거운 CRF 연산을 빼서 속도를 향상시킴.
#
# [DeepLab v3+]: v3의 ASPP(인코더) 뒤에 디코더를 달아서 초반 레벨 특징을 스킵 연결로 합침.
